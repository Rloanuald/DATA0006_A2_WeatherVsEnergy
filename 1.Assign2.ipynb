# %%
# According to DataFlowChart.png, Daniel advised the task allocations:
'''
step 1-3, everyone involved
step 4-6, 1-2 people do exploration and prediction, can have >1 models
step 7 , everyone
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pd.set_option('display.max_rows', None) <----doesnt work
df = pd.read_csv('weather_data.csv')
display(df.head())
#df.describe(include='all')
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2021                      15.6                      29.9
# 1  2/01/2021                      18.4                      29.0
# 2  3/01/2021                      17.0                      26.2
# 3  4/01/2021                      16.0                      18.6
# 4  5/01/2021                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# ...

# %%
# Min temp vs Date
dataframe = pd.read_csv('weather_data.csv')
display(dataframe.head())

plt.scatter(dataframe['Minimum temperature (°C)'],dataframe['Date'])
plt.scatter(dataframe['Maximum temperature (°C)'],dataframe['Date'])
plt.scatter(dataframe['9am Temperature (°C)'],dataframe['Date'])
plt.scatter(dataframe['3pm Temperature (°C)'],dataframe['Date'])
#plt.show()

#print("Pearson's correlation: " + str(dataframe['Date'].corr(dataframe['Minimum temperature (°C)'])))
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2021                      15.6                      29.9
# 1  2/01/2021                      18.4                      29.0
# 2  3/01/2021                      17.0                      26.2
# 3  4/01/2021                      16.0                      18.6
# 4  5/01/2021                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# ...

# %%
# Min temp vs Date
dataframe = pd.read_csv('weather_data.csv')
display(dataframe.head())

plt.scatter(dataframe['Maximum temperature (°C)'],dataframe['Date'])
#plt.show()

#print("Pearson's correlation: " + str(dataframe['Date'].corr(dataframe['Maximum temperature (°C)'])))
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2021                      15.6                      29.9
# 1  2/01/2021                      18.4                      29.0
# 2  3/01/2021                      17.0                      26.2
# 3  4/01/2021                      16.0                      18.6
# 4  5/01/2021                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# ...

# %%
# Min temp vs Date
dataframe = pd.read_csv('weather_data.csv')
display(dataframe.head())

plt.scatter(dataframe['9am Temperature (°C)'],dataframe['Date'])
#plt.show()

#print("Pearson's correlation: " + str(dataframe['Date'].corr(dataframe['9am Temperature (°C)'])))
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2021                      15.6                      29.9
# 1  2/01/2021                      18.4                      29.0
# 2  3/01/2021                      17.0                      26.2
# 3  4/01/2021                      16.0                      18.6
# 4  5/01/2021                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# ...

# %%
# display all rows
#df.iloc[:]

# display all index columns
df.columns
# Out:
# Index(['Date', 'Minimum temperature (°C)', 'Maximum temperature (°C)',
#        'Rainfall (mm)', 'Evaporation (mm)', 'Sunshine (hours)',
#        'Direction of maximum wind gust ', 'Speed of maximum wind gust (km/h)',
#        'Time of maximum wind gust', '9am Temperature (°C)',
#        '9am relative humidity (%)', '9am cloud amount (oktas)',
#        '9am wind direction', '9am wind speed (km/h)', '9am MSL pressure (hPa)',
#        '3pm Temperature (°C)', '3pm relative humidity (%)',
#        '3pm cloud amount (oktas)', '3pm wind direction',
#        '3pm wind speed (km/h)', '3pm MSL pressure (hPa)'],
#       dtype='object')

# %%
Index(['Date', 'Minimum temperature (°C)', 'Maximum temperature (°C)',
       '9am Temperature (°C)',
       '3pm Temperature (°C)', 
    ],
      dtype='object')

# %%
w_list = df.iloc[:]
w_index = df.columns

w_series = pd.Series(data = w_list,
                    index = w_index)

# %%
df = pd.read_csv('price_demand_data.csv')
display(df.head())
#df.describe(include='all')
df.columns[1]
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 0   VIC1  1/01/2021 0:30      4179.21           LOW
# 1   VIC1  1/01/2021 1:00      4047.76           LOW
# 2   VIC1  1/01/2021 1:30      3934.70           LOW
# 3   VIC1  1/01/2021 2:00      3766.45           LOW
# 4   VIC1  1/01/2021 2:30      3590.37           LOW
# 'SETTLEMENTDATE'

# %%
p_list = df.iloc[1]
p_index = df.columns[1]

p_series = pd.Series(data = p_list,
                    index = p_index)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn import preprocessing

dataset = pd.read_csv('weather_data.csv')
display(dataset.head())

#features = dataset[['mage','mheight','mnocig','mppwt','fage','fedyrs','fnocig','fheight']]
#classlabel = dataset['lowbwt']

features = dataset[['Date', 'Minimum temperature (°C)', 'Maximum temperature (°C)',
                   '9am Temperature (°C)',
                   '3pm Temperature (°C)', ]]
classlabel = dataset['Date']

features_train, features_test, class_train, class_test = train_test_split(features, classlabel, train_size=0.8, random_state=1)

dt = DecisionTreeClassifier(criterion='entropy', random_state=1)
dt.fit(features_train, class_train)
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2021                      15.6                      29.9
# 1  2/01/2021                      18.4                      29.0
# 2  3/01/2021                      17.0                      26.2
# 3  4/01/2021                      16.0                      18.6
# 4  5/01/2021                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# ...
