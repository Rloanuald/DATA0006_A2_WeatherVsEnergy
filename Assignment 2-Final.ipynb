# %% [markdown]
# # Step 1: Read the two dataframes

# %%
import pandas as pd
import datetime as dt
import numpy as np
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

# Read the two DataFrames
dataset1 = pd.read_csv('price_demand_data.csv') # Read CSV file "price_demand_data.csv"
dataset2 = pd.read_csv('weather_data.csv') # Read CSV file "weather_data.csv"
display(dataset1)
display(dataset2)
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 0       VIC1    1/01/2021 0:30      4179.21           LOW
# 1       VIC1    1/01/2021 1:00      4047.76           LOW
# 2       VIC1    1/01/2021 1:30      3934.70           LOW
# 3       VIC1    1/01/2021 2:00      3766.45           LOW
# 4       VIC1    1/01/2021 2:30      3590.37           LOW
# ...      ...               ...          ...           ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM
#
# [11664 rows x 4 columns]
#            Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0     1/01/2021                      15.6                      29.9
# 1     2/01/2021                      18.4                      29.0
# 2     3/01/2021                      17.0                      26.2
# 3     4/01/2021                      16.0                      18.6
# 4     5/01/2021                      15.9                      19.1
# ..          ...                       ...                       ...
# 238  27/08/2021                       4.6                      13.6
# 239  28/08/2021                       5.3                      17.8
# 240  29/08/2021                       9.1                      16.2
# 241  30/08/2021                       6.4                      17.6
# 242  31/08/2021                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 238            0.0               1.2               3.8
# 239            0.0               1.6               9.6
# 240            0.6               6.4               4.3
# 241            4.0               1.4               7.4
# 242            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 238                             SSW                               15.0
# 239                               N                               39.0
# 240                             NNE                               33.0
# 241                             NNW                               50.0
# 242                               N                               61.0
#
#     Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                       13:14                  19.2  ...
# 1                        8:22                  23.3  ...
# 2                       17:55                  18.3  ...
# 3                       16:03                  16.2  ...
# 4                       11:02                  17.2  ...
# ..                        ...                   ...  ...
# 238                     12:18                   7.7  ...
# 239                     13:14                   9.1  ...
# 240                      1:50                  10.6  ...
# 241                     14:04                  11.1  ...
# 242                     16:29                  13.5  ...
#
#      9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 0                           6                   N                     2
# 1                           7                 NNW                    17
# 2                           8                 WSW                     4
# 3                           8                 SSE                    11
# 4                           8                 SSE                    13
# ..                        ...                 ...                   ...
# 238                         7                                      Calm
# 239                         1                   N                     7
# 240                         7                   N                    13
# 241                         7                   N                    15
# 242                         7                   N                    17
#
#     9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                   1018.8                  28.1                         43
# 1                   1013.3                  28.7                         38
# 2                   1007.7                  23.5                         59
# 3                   1010.0                  18.2                         82
# 4                   1012.5                  18.2                         82
# ..                     ...                   ...                        ...
# 238                 1020.0                  12.8                         65
# 239                 1018.6                  17.4                         31
# 240                 1011.4                  12.8                         84
# 241                 1016.1                  16.8                         45
# 242                    NaN                  19.4                         43
#
#      3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                         5.0                   E                    13
# 1                         7.0                  SW                     4
# 2                         4.0                 SSW                     2
# 3                         8.0                 SSW                    17
# 4                         8.0                 SSE                    19
# ..                        ...                 ...                   ...
# 238                       7.0                 SSE                     7
# 239                       3.0                 NNW                    24
# 240                       7.0                   S                     6
# 241                       1.0                 NNW                    28
# 242                       6.0                   N                    30
#
#     3pm MSL pressure (hPa)
# 0                   1015.3
# 1                   1008.5
# 2                   1005.2
# 3                   1011.0
# 4                   1013.3
# ..                     ...
# 238                 1017.4
# 239                 1013.5
# 240                 1010.4
# 241                 1013.2
# 242                 1012.2
#
# [243 rows x 21 columns]

# %% [markdown]
# # Step 2: Merge (on Date column)

# %% [raw]
# To merge on the basis of common column, viz., 'Date', extracting the same format of the date from both datasets, so as to merge it on Date

# %% [markdown]
# ## Step 2i): dataset2 (Weather_data): Extracted date in a new column 'Date_key': dd/mm/yyy format

# %%
# Date extracted in a new column called 'Date_Key: dd/mm/yyyy' from dataset2: 'weather_data.csv'

#dataset2['Date_Key'] = dataset2['Date'].dt.datetime.strftime("%d/%m/%Y")
#dataset2.dtypes

date_time_2 = list(map(lambda x: dt.datetime.strptime(x,'%d/%m/%Y').strftime("%d/%m/%Y"), \
                       dataset2['Date']))
dataset2['Date_Key'] = date_time_2
display(dataset2.head())
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2021                      15.6                      29.9
# 1  2/01/2021                      18.4                      29.0
# 2  3/01/2021                      17.0                      26.2
# 3  4/01/2021                      16.0                      18.6
# 4  5/01/2021                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# 2                             WSW                               33.0
# 3                             SSE                               41.0
# 4                             SSE                               35.0
#
#   Time of maximum wind gust  9am Temperature (°C)  ...  9am wind direction  \
# 0                     13:14                  19.2  ...                   N
# 1                      8:22                  23.3  ...                 NNW
# 2                     17:55                  18.3  ...                 WSW
# 3                     16:03                  16.2  ...                 SSE
# 4                     11:02                  17.2  ...                 SSE
#
#    9am wind speed (km/h) 9am MSL pressure (hPa) 3pm Temperature (°C)  \
# 0                      2                 1018.8                 28.1
# 1                     17                 1013.3                 28.7
# 2                      4                 1007.7                 23.5
# 3                     11                 1010.0                 18.2
# 4                     13                 1012.5                 18.2
#
#    3pm relative humidity (%)  3pm cloud amount (oktas)  3pm wind direction  \
# 0                         43                       5.0                   E
# 1                         38                       7.0                  SW
# 2                         59                       4.0                 SSW
# 3                         82                       8.0                 SSW
# 4                         82                       8.0                 SSE
#
#    3pm wind speed (km/h) 3pm MSL pressure (hPa)    Date_Key
# 0                     13                 1015.3  01/01/2021
# 1                      4                 1008.5  02/01/2021
# 2                      2                 1005.2  03/01/2021
# 3                     17                 1011.0  04/01/2021
# 4                     19                 1013.3  05/01/2021
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Step 2ii): dataset1 (price_demand_data): Extracted date out of timestamp column in a new column 'Date_key': dd/mm/yyy format

# %%
# Date extracted out of timestamp col in a new col 'Date_Key: dd/mm/yyyy format' 
# from dataset1: 'price_demand_data.csv'

date_time_1 = list(map(lambda x: dt.datetime.strptime(x,'%d/%m/%Y %H:%M').strftime("%d/%m/%Y"), \
                       dataset1['SETTLEMENTDATE']))
dataset1['Date_Key'] = date_time_1
display(dataset1.head())
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY    Date_Key
# 0   VIC1  1/01/2021 0:30      4179.21           LOW  01/01/2021
# 1   VIC1  1/01/2021 1:00      4047.76           LOW  01/01/2021
# 2   VIC1  1/01/2021 1:30      3934.70           LOW  01/01/2021
# 3   VIC1  1/01/2021 2:00      3766.45           LOW  01/01/2021
# 4   VIC1  1/01/2021 2:30      3590.37           LOW  01/01/2021

# %% [markdown]
# ## Maximum TOTALDEMAND per day

# %%
# Given: Demand for every half an hour period each day
# Extracted: Maximum demand per day in a new column TOTALDEMAND_MAX
# Why: Bcz we want to predict 'maximum' demand per day

dataset1 = dataset1.join(dataset1.groupby('Date_Key')['TOTALDEMAND'].max(), on='Date_Key', rsuffix='_MAX')
display(dataset1)
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY    Date_Key  \
# 0       VIC1    1/01/2021 0:30      4179.21           LOW  01/01/2021
# 1       VIC1    1/01/2021 1:00      4047.76           LOW  01/01/2021
# 2       VIC1    1/01/2021 1:30      3934.70           LOW  01/01/2021
# 3       VIC1    1/01/2021 2:00      3766.45           LOW  01/01/2021
# 4       VIC1    1/01/2021 2:30      3590.37           LOW  01/01/2021
# ...      ...               ...          ...           ...         ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM  31/08/2021
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM  31/08/2021
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM  31/08/2021
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM  31/08/2021
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM  01/09/2021
#
#        TOTALDEMAND_MAX
# 0              5019.64
# 1              5019.64
# 2              5019.64
# 3              5019.64
# 4              5019.64
# ...                ...
# 11659          5779.56
# 11660          5779.56
# 11661          5779.56
# 11662          5779.56
# 11663          4811.27
#
# [11664 rows x 6 columns]

# %% [markdown]
# ## Converting Price: Categorical to Numerical

# %% [raw]
# Since, we want to predict the maximum daily price category, we convert price categories to numeric values, so as to choose the maximum out of the four categories.

# %%
# Replace Price categories with numeric values: 1,2,3,4 corresponding to the categories
# and created a new column 'PRICE_NUMERIC'

dataset1['PRICE_NUMERIC'] = dataset1['PRICECATEGORY']
dataset1['PRICE_NUMERIC'] = dataset1['PRICE_NUMERIC'].replace(['LOW','MEDIUM','HIGH','EXTREME'],[1,2,3,4])
display(dataset1)
dataset1.dtypes # check the data types of dataset1
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY    Date_Key  \
# 0       VIC1    1/01/2021 0:30      4179.21           LOW  01/01/2021
# 1       VIC1    1/01/2021 1:00      4047.76           LOW  01/01/2021
# 2       VIC1    1/01/2021 1:30      3934.70           LOW  01/01/2021
# 3       VIC1    1/01/2021 2:00      3766.45           LOW  01/01/2021
# 4       VIC1    1/01/2021 2:30      3590.37           LOW  01/01/2021
# ...      ...               ...          ...           ...         ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM  31/08/2021
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM  31/08/2021
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM  31/08/2021
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM  31/08/2021
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM  01/09/2021
#
#        TOTALDEMAND_MAX  PRICE_NUMERIC
# 0              5019.64              1
# 1              5019.64              1
# 2              5019.64              1
# 3              5019.64              1
# 4              5019.64              1
# ...                ...            ...
# 11659          5779.56              2
# 11660          5779.56              2
# 11661          5779.56              2
# 11662          5779.56              2
# 11663          4811.27              2
#
# [11664 rows x 7 columns]
# REGION              object
# SETTLEMENTDATE      object
# TOTALDEMAND        float64
# PRICECATEGORY       object
# Date_Key            object
# TOTALDEMAND_MAX    float64
# PRICE_NUMERIC        int64
# dtype: object

# %% [markdown]
# ## Maximum price per day

# %%
# Maximum price value corresponding to each date in a new column PRICE_NUMERIC_MAX 
dataset1 = dataset1.join(dataset1.groupby('Date_Key')['PRICE_NUMERIC'].max(), on='Date_Key', rsuffix='_MAX') 
display(dataset1)
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY    Date_Key  \
# 0       VIC1    1/01/2021 0:30      4179.21           LOW  01/01/2021
# 1       VIC1    1/01/2021 1:00      4047.76           LOW  01/01/2021
# 2       VIC1    1/01/2021 1:30      3934.70           LOW  01/01/2021
# 3       VIC1    1/01/2021 2:00      3766.45           LOW  01/01/2021
# 4       VIC1    1/01/2021 2:30      3590.37           LOW  01/01/2021
# ...      ...               ...          ...           ...         ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM  31/08/2021
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM  31/08/2021
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM  31/08/2021
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM  31/08/2021
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM  01/09/2021
#
#        TOTALDEMAND_MAX  PRICE_NUMERIC  PRICE_NUMERIC_MAX
# 0              5019.64              1                  1
# 1              5019.64              1                  1
# 2              5019.64              1                  1
# 3              5019.64              1                  1
# 4              5019.64              1                  1
# ...                ...            ...                ...
# 11659          5779.56              2                  2
# 11660          5779.56              2                  2
# 11661          5779.56              2                  2
# 11662          5779.56              2                  2
# 11663          4811.27              2                  2
#
# [11664 rows x 8 columns]

# %% [markdown]
# ## Dropped duplicates in Price_demand_data & created a new DF

# %% [raw]
# Since, we had multiple enteries for every date, we dropped the duplicates and extracted maximum demand and maximum price for each date in a new dataframe 'dataset_1'.

# %%
# Dropped the duplicates in 'Price_demand_data' and created a new dataframe 'dataset_1' 
# with selected 4 columns: Region, Date, Maximum Demand, Maximum Price

dataset_1 = dataset1[['REGION', 'Date_Key', 'TOTALDEMAND_MAX', 'PRICE_NUMERIC_MAX']].drop_duplicates(subset=['Date_Key'])
display(dataset_1)
# Out:
#       REGION    Date_Key  TOTALDEMAND_MAX  PRICE_NUMERIC_MAX
# 0       VIC1  01/01/2021          5019.64                  1
# 47      VIC1  02/01/2021          4964.35                  1
# 95      VIC1  03/01/2021          4503.31                  1
# 143     VIC1  04/01/2021          4764.18                  1
# 191     VIC1  05/01/2021          4800.64                  1
# ...      ...         ...              ...                ...
# 11471   VIC1  28/08/2021          5716.32                  2
# 11519   VIC1  29/08/2021          6227.89                  4
# 11567   VIC1  30/08/2021          6072.91                  3
# 11615   VIC1  31/08/2021          5779.56                  2
# 11663   VIC1  01/09/2021          4811.27                  2
#
# [244 rows x 4 columns]

# %% [markdown]
# ## Merged on Date: Data from 01/01/2021 - 31/08/2021

# %%
# merge 2 datasets: dataset_1 & dataset2 on 'Date_Key' using Inner join

dataset = pd.merge(dataset_1, dataset2, on = 'Date_Key')
dataset
# Out:
#     REGION    Date_Key  TOTALDEMAND_MAX  PRICE_NUMERIC_MAX        Date  \
# 0     VIC1  01/01/2021          5019.64                  1   1/01/2021
# 1     VIC1  02/01/2021          4964.35                  1   2/01/2021
# 2     VIC1  03/01/2021          4503.31                  1   3/01/2021
# 3     VIC1  04/01/2021          4764.18                  1   4/01/2021
# 4     VIC1  05/01/2021          4800.64                  1   5/01/2021
# ..     ...         ...              ...                ...         ...
# 238   VIC1  27/08/2021          6769.89                  4  27/08/2021
# 239   VIC1  28/08/2021          5716.32                  2  28/08/2021
# 240   VIC1  29/08/2021          6227.89                  4  29/08/2021
# 241   VIC1  30/08/2021          6072.91                  3  30/08/2021
# 242   VIC1  31/08/2021          5779.56                  2  31/08/2021
#
#      Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                        15.6                      29.9            0.0
# 1                        18.4                      29.0            0.0
# 2                        17.0                      26.2           12.6
# 3                        16.0                      18.6            2.6
# 4                        15.9                      19.1           11.2
# ..                        ...                       ...            ...
# 238                       4.6                      13.6            0.0
# 239                       5.3                      17.8            0.0
# 240                       9.1                      16.2            0.6
# 241                       6.4                      17.6            4.0
# 242                      11.0                      20.1            0.0
#
#      Evaporation (mm)  Sunshine (hours)  ... 9am cloud amount (oktas)  \
# 0                 2.8               9.3  ...                        6
# 1                 9.4               1.3  ...                        7
# 2                 4.8               7.1  ...                        8
# 3                 3.8               0.0  ...                        8
# 4                 1.0               0.0  ...                        8
# ..                ...               ...  ...                      ...
# 238               1.2               3.8  ...                        7
# 239               1.6               9.6  ...                        1
# 240               6.4               4.3  ...                        7
# 241               1.4               7.4  ...                        7
# 242               5.8               3.6  ...                        7
#
#      9am wind direction 9am wind speed (km/h)  9am MSL pressure (hPa)  \
# 0                     N                     2                  1018.8
# 1                   NNW                    17                  1013.3
# 2                   WSW                     4                  1007.7
# 3                   SSE                    11                  1010.0
# 4                   SSE                    13                  1012.5
# ..                  ...                   ...                     ...
# 238                                      Calm                  1020.0
# 239                   N                     7                  1018.6
# 240                   N                    13                  1011.4
# 241                   N                    15                  1016.1
# 242                   N                    17                     NaN
#
#      3pm Temperature (°C)  3pm relative humidity (%) 3pm cloud amount (oktas)  \
# 0                    28.1                         43                      5.0
# 1                    28.7                         38                      7.0
# 2                    23.5                         59                      4.0
# 3                    18.2                         82                      8.0
# 4                    18.2                         82                      8.0
# ..                    ...                        ...                      ...
# 238                  12.8                         65                      7.0
# 239                  17.4                         31                      3.0
# 240                  12.8                         84                      7.0
# 241                  16.8                         45                      1.0
# 242                  19.4                         43                      6.0
#
#     3pm wind direction  3pm wind speed (km/h)  3pm MSL pressure (hPa)
# 0                    E                     13                  1015.3
# 1                   SW                      4                  1008.5
# 2                  SSW                      2                  1005.2
# 3                  SSW                     17                  1011.0
# 4                  SSE                     19                  1013.3
# ..                 ...                    ...                     ...
# 238                SSE                      7                  1017.4
# 239                NNW                     24                  1013.5
# 240                  S                      6                  1010.4
# 241                NNW                     28                  1013.2
# 242                  N                     30                  1012.2
#
# [243 rows x 25 columns]

# %%
# Check data types of the new merged dataset

dataset.dtypes
# Out:
# REGION                                object
# Date_Key                              object
# TOTALDEMAND_MAX                      float64
# PRICE_NUMERIC_MAX                      int64
# Date                                  object
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Evaporation (mm)                     float64
# Sunshine (hours)                     float64
# Direction of maximum wind gust        object
# Speed of maximum wind gust (km/h)    float64
# Time of maximum wind gust             object
# 9am Temperature (°C)                 float64
# 9am relative humidity (%)            float64
# 9am cloud amount (oktas)               int64
# 9am wind direction                    object
# 9am wind speed (km/h)                 object
# 9am MSL pressure (hPa)               float64
# 3pm Temperature (°C)                 float64
# 3pm relative humidity (%)              int64
# 3pm cloud amount (oktas)             float64
# 3pm wind direction                    object
# 3pm wind speed (km/h)                 object
# 3pm MSL pressure (hPa)               float64
# dtype: object

# %%
# check if the columns in dataset is null?
# .isnull(): The isnull() method returns a DataFrame object where all the values are replaced 
# with a Boolean value True for NULL values, and otherwise False

dataset.isnull().sum()
# Out:
# REGION                               0
# Date_Key                             0
# TOTALDEMAND_MAX                      0
# PRICE_NUMERIC_MAX                    0
# Date                                 0
# Minimum temperature (°C)             1
# Maximum temperature (°C)             1
# Rainfall (mm)                        2
# Evaporation (mm)                     0
# Sunshine (hours)                     0
# Direction of maximum wind gust       3
# Speed of maximum wind gust (km/h)    3
# Time of maximum wind gust            3
# 9am Temperature (°C)                 1
# 9am relative humidity (%)            1
# 9am cloud amount (oktas)             0
# 9am wind direction                   1
# 9am wind speed (km/h)                1
# 9am MSL pressure (hPa)               2
# 3pm Temperature (°C)                 0
# 3pm relative humidity (%)            0
# 3pm cloud amount (oktas)             1
# 3pm wind direction                   0
# 3pm wind speed (km/h)                0
# 3pm MSL pressure (hPa)               1
# dtype: int64

# %% [raw]
# Minimum temperature (°C): 0
# Maximum temperature (°C): 0
# Rainfall (mm): 0
# Evaporation (mm): 0
# Sunshine (hours): 0
# Speed of maximum wind gust (km/h): 0
# 9am Temperature (°C): 1
# 3pm Temperature (°C) : 0

# %%
# Check if the columns in dataset have values missing?
# .isna(): Indicates whether values are missing (NaN in numeric arrays, None or NaN in object arrays,
# NaT in datetimelike)
dataset.isna().sum()
# Out:
# REGION                               0
# Date_Key                             0
# TOTALDEMAND_MAX                      0
# PRICE_NUMERIC_MAX                    0
# Date                                 0
# Minimum temperature (°C)             1
# Maximum temperature (°C)             1
# Rainfall (mm)                        2
# Evaporation (mm)                     0
# Sunshine (hours)                     0
# Direction of maximum wind gust       3
# Speed of maximum wind gust (km/h)    3
# Time of maximum wind gust            3
# 9am Temperature (°C)                 1
# 9am relative humidity (%)            1
# 9am cloud amount (oktas)             0
# 9am wind direction                   1
# 9am wind speed (km/h)                1
# 9am MSL pressure (hPa)               2
# 3pm Temperature (°C)                 0
# 3pm relative humidity (%)            0
# 3pm cloud amount (oktas)             1
# 3pm wind direction                   0
# 3pm wind speed (km/h)                0
# 3pm MSL pressure (hPa)               1
# dtype: int64

# %%
# Replaced missing values in the given columns by the mean value of the said column


dataset = dataset.replace('Calm',0)

dataset['9am wind speed (km/h)'] = dataset['9am wind speed (km/h)'].astype(float)
dataset['3pm wind speed (km/h)'] = dataset['3pm wind speed (km/h)'].astype(float)

dataset['Minimum temperature (°C)'].replace([numpy.nan], dataset['Minimum temperature (°C)'].mean(), inplace=True)
dataset['Maximum temperature (°C)'].replace([numpy.nan], dataset['Maximum temperature (°C)'].mean(), inplace=True)
dataset['Rainfall (mm)'].replace([numpy.nan], dataset['Rainfall (mm)'].mean(), inplace=True)
dataset['Speed of maximum wind gust (km/h)'].replace([numpy.nan], dataset['Speed of maximum wind gust (km/h)'].mean(), inplace=True)
dataset['9am Temperature (°C)'].replace([numpy.nan], dataset['9am Temperature (°C)'].mean(), inplace=True)
dataset['9am wind speed (km/h)'].replace([numpy.nan], dataset['9am wind speed (km/h)'].mean(), inplace=True)
dataset['3pm wind speed (km/h)'].replace([numpy.nan], dataset['3pm wind speed (km/h)'].mean(), inplace=True)
dataset['9am relative humidity (%)'].replace([numpy.nan], dataset['9am relative humidity (%)'].mean(), inplace=True)
dataset['3pm cloud amount (oktas)'].replace([numpy.nan], dataset['3pm cloud amount (oktas)'].mean(), inplace=True)
dataset['9am MSL pressure (hPa)'].replace([numpy.nan], dataset['9am MSL pressure (hPa)'].mean(), inplace=True)
dataset['3pm MSL pressure (hPa)'].replace([numpy.nan], dataset['3pm MSL pressure (hPa)'].mean(), inplace=True)
dataset['9am cloud amount (oktas)'].replace([numpy.nan], dataset['9am cloud amount (oktas)'].mean(), inplace=True)

# %%
# Check if there exist any missing values in the above columns.

print(dataset['Minimum temperature (°C)'].isna().sum())
print(dataset['Maximum temperature (°C)'].isna().sum())
print(dataset['Rainfall (mm)'].isna().sum())
print(dataset['Speed of maximum wind gust (km/h)'].isna().sum())
print(dataset['9am Temperature (°C)'].isna().sum())
print(dataset['9am wind speed (km/h)'].isna().sum())
print(dataset['3pm wind speed (km/h)'].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# # Pairwise pearson r correlation matrix between chosen features

# %%
# Pairwise pearson r correlation matrix between different variables
corr = dataset[['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Rainfall (mm)', 'Evaporation (mm)', 'Sunshine (hours)', 'Speed of maximum wind gust (km/h)', '9am Temperature (°C)', '3pm Temperature (°C)','9am wind speed (km/h)','3pm wind speed (km/h)' ]].corr(method='pearson')
# corr = dataset[['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Rainfall (mm)', 'Evaporation (mm)', 'Sunshine (hours)', 'Speed of maximum wind gust (km/h)' ]].corr(method='pearson')
# corr = dataset[['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Evaporation (mm)', '9am Temperature (°C)', '3pm Temperature (°C)' ]].corr(method='pearson')
corr
# Out:
#                                    Minimum temperature (°C)  \
# Minimum temperature (°C)                           1.000000
# Maximum temperature (°C)                           0.707525
# Rainfall (mm)                                      0.043400
# Evaporation (mm)                                   0.655132
# Sunshine (hours)                                   0.081809
# Speed of maximum wind gust (km/h)                  0.055599
# 9am Temperature (°C)                               0.915726
# 3pm Temperature (°C)                               0.661643
# 9am wind speed (km/h)                             -0.003146
# 3pm wind speed (km/h)                             -0.022677
#
#                                    Maximum temperature (°C)  Rainfall (mm)  \
# Minimum temperature (°C)                           0.707525       0.043400
# Maximum temperature (°C)                           1.000000      -0.124821
# Rainfall (mm)                                     -0.124821       1.000000
# Evaporation (mm)                                   0.620699      -0.044562
# Sunshine (hours)                                   0.469055      -0.146530
# Speed of maximum wind gust (km/h)                 -0.056155       0.042003
# 9am Temperature (°C)                               0.820029      -0.020988
# 3pm Temperature (°C)                               0.965134      -0.126890
# 9am wind speed (km/h)                             -0.073599      -0.073477
# 3pm wind speed (km/h)                             -0.028475       0.047508
#
#                                    Evaporation (mm)  Sunshine (hours)  \
# Minimum temperature (°C)                   0.655132          0.081809
# Maximum temperature (°C)                   0.620699          0.469055
# Rainfall (mm)                             -0.044562         -0.146530
# Evaporation (mm)                           1.000000          0.273256
# Sunshine (hours)                           0.273256          1.000000
# Speed of maximum wind gust (km/h)          0.158109         -0.058401
# 9am Temperature (°C)                       0.705835          0.197050
# 3pm Temperature (°C)                       0.560214          0.487546
# 9am wind speed (km/h)                      0.122228          0.003008
# 3pm wind speed (km/h)                      0.022986          0.091350
#
#                                    Speed of maximum wind gust (km/h)  \
# Minimum temperature (°C)                                    0.055599
# Maximum temperature (°C)                                   -0.056155
# Rainfall (mm)                                               0.042003
# Evaporation (mm)                                            0.158109
# Sunshine (hours)                                           -0.058401
# Speed of maximum wind gust (km/h)                           1.000000
# 9am Temperature (°C)                                        0.108981
# 3pm Temperature (°C)                                       -0.097803
# 9am wind speed (km/h)                                       0.608704
# 3pm wind speed (km/h)                                       0.674292
#
#                                    9am Temperature (°C)  3pm Temperature (°C)  \
# Minimum temperature (°C)                       0.915726              0.661643
# Maximum temperature (°C)                       0.820029              0.965134
# Rainfall (mm)                                 -0.020988             -0.126890
# Evaporation (mm)                               0.705835              0.560214
# Sunshine (hours)                               0.197050              0.487546
# Speed of maximum wind gust (km/h)              0.108981             -0.097803
# 9am Temperature (°C)                           1.000000              0.761579
# 3pm Temperature (°C)                           0.761579              1.000000
# 9am wind speed (km/h)                          0.036497             -0.087455
# 3pm wind speed (km/h)                          0.022947              0.006479
#
#                                    9am wind speed (km/h)  \
# Minimum temperature (°C)                       -0.003146
# Maximum temperature (°C)                       -0.073599
# Rainfall (mm)                                  -0.073477
# Evaporation (mm)                                0.122228
# Sunshine (hours)                                0.003008
# Speed of maximum wind gust (km/h)               0.608704
# 9am Temperature (°C)                            0.036497
# 3pm Temperature (°C)                           -0.087455
# 9am wind speed (km/h)                           1.000000
# 3pm wind speed (km/h)                           0.396588
#
#                                    3pm wind speed (km/h)
# Minimum temperature (°C)                       -0.022677
# Maximum temperature (°C)                       -0.028475
# Rainfall (mm)                                   0.047508
# Evaporation (mm)                                0.022986
# Sunshine (hours)                                0.091350
# Speed of maximum wind gust (km/h)               0.674292
# 9am Temperature (°C)                            0.022947
# 3pm Temperature (°C)                            0.006479
# 9am wind speed (km/h)                           0.396588
# 3pm wind speed (km/h)                           1.000000

# %% [markdown]
# # Plotting the heatmap of the above chosen features

# %%
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style  type="text/css" >
# #T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col0,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col1,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col2,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col3,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col4,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col5,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col6,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col7,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row8_col8,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col1{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col2,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col2{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col3,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col0{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col4{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col5{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col6,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col0{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col7{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col8,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col0,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col4{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row0_col9{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col0,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col6{
#             background-color:  #f7a889;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col2,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col2,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row8_col0{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col3,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col8{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col4{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col5,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col5{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col6{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col7,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col1{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col8,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col8{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row1_col9,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col1,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col3,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col4,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col6,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col7,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col2,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col5,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col8,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row9_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col0,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row8_col2,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row9_col3{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col5,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col6{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row2_col9{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col0,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col1{
#             background-color:  #f7b99e;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col2{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col4{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col7{
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col8,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col3{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row3_col9,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col9{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col0{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col1{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col3{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col6{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col7{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col8,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row9_col1{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row4_col9,#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col8{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col1{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col7{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row5_col9{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col1{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col2{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col3{
#             background-color:  #f7a688;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col4{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col5{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row6_col7{
#             background-color:  #f08a6c;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col3{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col4{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_0779b56e_14bc_11ed_95f6_f2465a63a0d3row7_col6{
#             background-color:  #f29274;

# %% [raw]
# FROM THE HEATMAP:
#
# demand: min temp, max temp, evaporation, 9am temp, 3pm temp
# price: min temp, max temp, evaporation, sunshine, 9am temp, 3pm temp
#
# INTERPRETATION:
#
# Each square shows the correlation between the variables on each axis. The diagonals are all 1/dark blue because those squares are correlating each variable to itself (so it's a perfect correlation). For the rest the larger the number and darker the color (blue), the higher the correlation between the two variables.
#
# RELATED:
# 1. Minimum temperature: Closely related to Maximum temperature (0.70), Evaporation (0.65), 9am Temperature (0.91), 3pm Temperature (0.66)
# 2. Maximum temperature: Closely related to Minimum temperature (0.70), Evaporation (0.62), 9am Temperature (0.82), 3pm Temperature (0.96)
# 3. Evaporation: Closely related to Minimum temperature (0.65), Maximum Temperature (0.62), 9am Temperature (0.70), 3pm Temperature (0.76)
# 4. Sunshine: Moderately related to Maximum Temperature (0.47) and 3pm Temperature (0.49)
# 5. 9am Temperature: Closely related to Minimum temperature (0.91), Maximum Temperature (0.82), Evaporation (0.70), 3pm Temperature (0.76)
# 6. 3pm Temperature: Closely related to Minimum temperature (0.66), Maximum Temperature (0.96),        Evaporation (0.56), Sunshine hours (0.49), 9am Temperature (0.76)
#
# NOT RELATED:
# i.  Rainfall: Not related to considered variables
# ii. Speed of maximum wind gust: Not related to considered variables

# %% [markdown]
# # Plotting the heatmap for all the features

# %%
plt.figure(figsize=(20,10))
sns.heatmap(dataset.corr(), annot = True);

# %% [markdown]
# # 2nd model: Predicts Max Daily Price: CLASSIFICATION: KNN

# %%
import pandas as pd
from sklearn.model_selection import train_test_split # For splitting
from sklearn.metrics import accuracy_score # To check accuracy of the prediction
from sklearn import neighbors # To produce/generate KNeighborsClassifier
from sklearn import preprocessing # To scale/normalise the features

# Select features (input)
features = dataset[['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Evaporation (mm)', 'Sunshine (hours)','9am Temperature (°C)', '3pm Temperature (°C)' ]]

# What we want to predict (output)
classlabel = dataset['PRICE_NUMERIC_MAX']

# Splitting
features_train, features_test, class_train, class_test = train_test_split(features, classlabel, train_size = 0.8, random_state = 1)

# Scale/Normalize the features
scaler = preprocessing.StandardScaler().fit(features_train) 
features_train = scaler.transform(features_train) 
features_test = scaler.transform(features_test)

# Generating KNN classifier model & import neighbors from sklearn library
knn = neighbors.KNeighborsClassifier(n_neighbors = 5)

# Creating model: Fitting features & classlabel in training data set
knn.fit(features_train, class_train)

# Produce predictions & check its .accuracy_score() on testing data set
predictions = knn.predict(features_test)
print(accuracy_score(class_test, predictions))
# Out:
# 0.5510204081632653

# %% [raw]
# KNN classifier came out to be 55.1% effective when applied to this testing set.

# %% [markdown]
# ## 2nd model: Predict max daily price: CLASSIFICATION: DECISION TREES

# %%
import pandas as pd
from sklearn.model_selection import train_test_split # For splitting
from sklearn.tree import DecisionTreeClassifier # For generating the model
from sklearn.metrics import accuracy_score # To check accuracy of the prediction
from sklearn import preprocessing

# Select features (input)
features = dataset[['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Evaporation (mm)', 'Sunshine (hours)','9am Temperature (°C)', '3pm Temperature (°C)']]

# What we want to predict (output)
classlabel = dataset['PRICE_NUMERIC_MAX']

# Splitting
features_train, features_test, class_train, class_test = train_test_split(features, classlabel, train_size = 0.8, random_state = 1)

# scaling/Normalizing the values
scaler = preprocessing.StandardScaler().fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

#  Generating the decision tree model
dt = DecisionTreeClassifier(criterion = 'entropy', random_state = 1, max_depth = 3)

# Create tree = Fitting features and classlabel into the model
dt.fit(features_train, class_train)

# Check the accuracy_score of the prediction
predictions = dt.predict(features_test) # predictions based on testing set
print(accuracy_score(class_test, predictions)) # report how well these predictiosn based on acc_score
# Out:
# 0.42857142857142855

# %% [raw]
# Decision tree classifier came out to be 42.8% effective when applied to this testing set.

# %% [markdown]
# ## Visualising the Decision Tree classifier: Plot it

# %% [markdown]
# # To plot the decision tree just created.
# from sklearn import tree
# import matplotlib.pyplot as plt
#
# fig = plt.figure(figsize=(25,20))
# featurenames = ['TOTALDEMAND_MAX', 'Minimum temperature (°C)', 'Maximum temperature (°C)', 'Rainfall (mm)', 'Evaporation (mm)', 'Sunshine (hours)', 'Speed of maximum wind gust (km/h)']
# tree.plot_tree(dt, feature_names=featurenames)

# %% [markdown]
# # 1st model: Predict max daily demand: LINEAR REGRESSION MODEL

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import linear_model

# Choose the features (input)
X = dataset[['Minimum temperature (°C)','Evaporation (mm)', '3pm Temperature (°C)','Speed of maximum wind gust (km/h)','Sunshine (hours)','3pm relative humidity (%)','3pm cloud amount (oktas)']]

# What we have to predict (output)
Y = dataset['TOTALDEMAND_MAX']

# Splitting the data into training set and testing set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.8, random_state = 1)

# Generate the regression model (import .linear_model to use .LinearRegression() func)
lm = linear_model.LinearRegression()

# Create/ Produce the model: Fit training data into model
model = lm.fit(X_train, Y_train)
display(model)

# Predict coefficient & intercept from linear regression model(lm)
print(lm.coef_, lm.intercept_)

# %% [raw]
# Equation used to predict the maximum daily energy use is:
# 6735.50(intercept) + (-156.02 * Minimum temperature) + (56.49 * Maximum temperature) + (-5.36 * Rainfall) + (23.68 * Evaporation) + (-51.81 * Sunshine) + (8.19 * Speed of maximum wind gust)

# %% [markdown]
# ## Access how regression model is doing

# %%
from sklearn.metrics import mean_squared_error, r2_score
r2_test = lm.score(X_test, Y_test) #on testing data
print(r2_test)

# %% [raw]
# 22.7% of variation seen in these datapoints is explained by these parameters we have identified here.

# %% [markdown]
# ## How close these predictions are?

# %%
print(lm.predict(X_test.head())) # Predict values what we might think max demand should be
print(Y_test.head()) # What we actually had based on the Y values

# %% [raw]
# On 01/01/2021: Predicted max demand was 5624.82, its actual value is 5527.62 # difference: 97 approx
# On 02/01/2021: Predicted max demand was 6604.91, its actual value is 5779.56 # difference: 825 approx
# On 03/01/2021: Predicted max demand was 6665.83, its actual value is 6817.65 # difference: 152 approx
# On 04/01/2021: Predicted max demand was 6161.06, its actual value is 6183.00 # difference: 22 approx
# On 05/01/2021: Predicted max demand was 6015.02, its actual value is 5769.10 # difference: 246 approx
#
# This implies: There is not much difference between the predicted max demand and observed max demand, So, overall its a decently good model that we have.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold

##get just the features
data = dataset[['Minimum temperature (°C)','Maximum temperature (°C)','Rainfall (mm)','Evaporation (mm)','Sunshine (hours)','Speed of maximum wind gust (km/h)',\
          '9am Temperature (°C)','9am wind speed (km/h)','3pm Temperature (°C)','3pm wind speed (km/h)']]


##get just the class labels
classlabel=dataset['PRICE_NUMERIC_MAX']

k=5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

acc_score = []
acc_score_dt = []

for train_index, test_index in kf.split(data):
    #Perform the split for this fold
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index, :]
    y_train, y_test = classlabel[train_index], classlabel[test_index]

    #Scale the data
    scaler = preprocessing.StandardScaler().fit(X_train)
    X_train=scaler.transform(X_train)
    X_test=scaler.transform(X_test)

    #Impute missing values via mean imputation
    imp = SimpleImputer(missing_values=np.nan, strategy='mean')
    X_train = imp.fit_transform(X_train)
    X_test = imp.transform(X_test)
    
    #Train k-nn classifier
    knn = neighbors.KNeighborsClassifier(n_neighbors=5)
    dt = DecisionTreeClassifier(criterion="entropy",)
    
    # STEP 2: Fitting data / Training
    knn.fit(X_train, y_train)
    dt.fit(X_train, y_train)

   # STEP 3: Prediction / Test
    y_pred=knn.predict(X_test)
    y_pred_dt = dt.predict(X_test)
    
    # STEP 4: Eval
    acc_score.append(accuracy_score(y_test, y_pred))
    acc_score_dt.append(accuracy_score(y_test, y_pred_dt))
    
    
    

print(acc_score)
#Display average of accuracy scores
avg_acc_score = sum(acc_score)/k
print(avg_acc_score)



print (acc_score_dt)
avg_acc_score_dt = sum(acc_score_dt)/k
print(avg_acc_score_dt)
# Out:
# [0.5102040816326531, 0.46938775510204084, 0.4489795918367347, 0.4375, 0.5]
# 0.47321428571428575
# [0.42857142857142855, 0.4897959183673469, 0.4897959183673469, 0.375, 0.3958333333333333]
# 0.4357993197278912

# %% [markdown]
# ## Chi Squared Test

# %%
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
import math
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler


X = dataset[['Minimum temperature (°C)','Maximum temperature (°C)','Rainfall (mm)','Evaporation (mm)','Sunshine (hours)','Speed of maximum wind gust (km/h)','9am Temperature (°C)','9am relative humidity (%)'\
           ,'9am cloud amount (oktas)','9am wind speed (km/h)','9am MSL pressure (hPa)','3pm Temperature (°C)','3pm relative humidity (%)','3pm cloud amount (oktas)','3pm wind speed (km/h)','3pm MSL pressure (hPa)']]
y = dataset['PRICE_NUMERIC_MAX']

#Scale the data
scaler = MinMaxScaler()

scaled = scaler.fit_transform(X)
# Instantiate
feature_selector = SelectKBest(chi2, k=6)

   
# Perform selection
X_kbest = feature_selector.fit_transform(X, y)
#X_test = feature_selector.transform(X_test)

print('Original number of features:', X.shape)
print('Reduced number of features:', X_kbest.shape)

#X_train, X_test, y_train, y_test = train_test_split(X_train, cl, train_size =0.8, random_state = 1)

k=15
kf = KFold(n_splits=k, shuffle=True, random_state=42)

acc_score = []
acc_score_dt = []

for train_index, test_index in kf.split(X_kbest):
    #Perform the split for this fold
    X_train,X_test=X_kbest[train_index],X_kbest[test_index]
    y_train,y_test=y[train_index],y[test_index]
    
    
    #Scale the data
    scaler = preprocessing.StandardScaler().fit(X_train)
    X_train=scaler.transform(X_train)
    X_test=scaler.transform(X_test)
    
    #Impute missing values via mean imputation
    imp = SimpleImputer(missing_values=np.nan, strategy='mean')
    X_train = imp.fit_transform(X_train)
    X_test = imp.transform(X_test)
    
    #Train k-nn classifier
    knn = neighbors.KNeighborsClassifier(n_neighbors=5)
    dt = DecisionTreeClassifier(criterion="entropy")
    
    # STEP 2: Fitting data / Training
    knn.fit(X_train, y_train)
    dt.fit(X_train, y_train)

   # STEP 3: Prediction / Test
    y_pred=knn.predict(X_test)
    y_pred_dt = dt.predict(X_test)
    
    # STEP 4: Eval
    acc_score.append(accuracy_score(y_test, y_pred))
    acc_score_dt.append(accuracy_score(y_test, y_pred_dt))
    
    
print('Accuracy of each fold for knn - {}'.format(acc_score))
avg_acc_score = sum(acc_score)/k
print('Avg accuracy : {}'.format(avg_acc_score))

print('Accuracy of each fold for Decision Tree- {}'.format(acc_score_dt))
avg_acc_score_dt = sum(acc_score_dt)/k
print('Avg accuracy : {}'.format(avg_acc_score_dt))
# Out:
# Original number of features: (243, 16)
# Reduced number of features: (243, 6)
# Accuracy of each fold for knn - [0.35294117647058826, 0.6470588235294118, 0.47058823529411764, 0.5625, 0.5, 0.375, 0.625, 0.3125, 0.6875, 0.4375, 0.625, 0.625, 0.5, 0.5625, 0.375]
# Avg accuracy : 0.5105392156862745
# Accuracy of each fold for Decision Tree- [0.29411764705882354, 0.47058823529411764, 0.4117647058823529, 0.4375, 0.5, 0.3125, 0.3125, 0.3125, 0.5, 0.375, 0.5, 0.5, 0.375, 0.3125, 0.6875]
# Avg accuracy : 0.4200980392156862

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn import neighbors
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

data2 = dataset[['Minimum temperature (°C)','Maximum temperature (°C)','Rainfall (mm)','Evaporation (mm)','Sunshine (hours)','Speed of maximum wind gust (km/h)','9am Temperature (°C)','9am relative humidity (%)'\
           ,'9am cloud amount (oktas)','9am wind speed (km/h)','9am MSL pressure (hPa)','3pm Temperature (°C)','3pm relative humidity (%)','3pm cloud amount (oktas)','3pm wind speed (km/h)','3pm MSL pressure (hPa)']]
cl2 = dataset['PRICE_NUMERIC_MAX']

X_train, X_test, y_train, y_test = train_test_split(data2,cl2, train_size =0.66, random_state = 42)

k=5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

acc_score = []
acc_score_dt = []

for train_index, test_index in kf.split(data2):
    #Scale the data
    scaler = preprocessing.StandardScaler().fit(X_train)
    X_train=scaler.transform(X_train)
    X_test=scaler.transform(X_test)

    #Impute missing values via mean imputation
    imp = SimpleImputer(missing_values=np.nan, strategy='mean')
    X_train = imp.fit_transform(X_train)
    X_test = imp.transform(X_test)

    pca = PCA(n_components = 3)
    X_train = pca.fit_transform(X_train)
    X_test = pca.transform(X_test)

    #Train k-nn classifier
    knn = neighbors.KNeighborsClassifier(n_neighbors=5)
    dt = DecisionTreeClassifier(criterion="entropy", max_depth = 5)

    # STEP 2: Fitting data / Training
    knn.fit(X_train, y_train)
    dt.fit(X_train, y_train)

    # STEP 3: Prediction / Test
    y_pred=knn.predict(X_test)
    y_pred_dt = dt.predict(X_test)

    # STEP 4: Eval
    acc_score.append(accuracy_score(y_test, y_pred))
    acc_score_dt.append(accuracy_score(y_test, y_pred_dt))

print('Accuracy of each fold for knn - {}'.format(acc_score))
avg_acc_score = sum(acc_score)/k
print('Avg accuracy : {}'.format(avg_acc_score))

print('Accuracy of each fold for Decision Tree- {}'.format(acc_score_dt))
avg_acc_score_dt = sum(acc_score_dt)/k
print('Avg accuracy : {}'.format(avg_acc_score_dt))
# Out:
# Accuracy of each fold for knn - [0.4819277108433735, 0.4939759036144578, 0.4939759036144578, 0.4939759036144578, 0.4939759036144578]
# Avg accuracy : 0.4915662650602409
# Accuracy of each fold for Decision Tree- [0.4819277108433735, 0.39759036144578314, 0.43373493975903615, 0.40963855421686746, 0.46987951807228917]
# Avg accuracy : 0.4385542168674699
